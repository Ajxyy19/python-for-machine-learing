# %%
import pandas as pd

df = pd.DataFrame({
    'Animal': ['Tiger', 'Lion', 'Cheetah', 'Deer'],
    'Max speed': ['130', '110', '180', '160']
})

print(df)
# Out:
#     Animal Max speed
# 0    Tiger       130
# 1     Lion       110
# 2  Cheetah       180
# 3     Deer       160

# %%
import pandas as pd

# Original DataFrame
df = pd.DataFrame({
    'Animal': ['Tiger', 'Lion', 'Cheetah', 'Deer'],
    'Max speed': ['130', '110', '180', '160']
})

# Convert 'Max speed' to numeric
df['Max speed'] = pd.to_numeric(df['Max speed'])

# Group by 'Animal' and sum
b = df.groupby('Animal').sum()

print("\nOriginal DataFrame\n", df)
print("\nGroup by Animal using sum\n", b)
# Out:
# Original DataFrame
#      Animal  Max speed
# 0    Tiger        130
# 1     Lion        110
# 2  Cheetah        180
# 3     Deer        160
#
# Group by Animal using sum
#           Max speed
# Animal
# Cheetah        180
# Deer           160
# Lion           110
# Tiger          130

# %%
import pandas as pd

# Original DataFrame
df = pd.DataFrame({
    'Animal': ['Tiger', 'Lion', 'Cheetah', 'Deer'],
    'Max speed': ['130', '110', '180', '160']
})

# Convert 'Max speed' to numeric
df['Max speed'] = pd.to_numeric(df['Max speed'])

# Group by 'Animal' and count entries
c = df.groupby('Animal').count()

print("\nOriginal DataFrame\n", df)
print("\nGroup by Animal using count\n", c)
# Out:
# Original DataFrame
#      Animal  Max speed
# 0    Tiger        130
# 1     Lion        110
# 2  Cheetah        180
# 3     Deer        160
#
# Group by Animal using count
#           Max speed
# Animal
# Cheetah          1
# Deer             1
# Lion             1
# Tiger            1

# %%
import pandas as pd

# Original DataFrame
df = pd.DataFrame({
    'Animal': ['Tiger', 'Lion', 'Cheetah', 'Deer'],
    'Max speed': ['130', '110', '180', '160']
})

# Convert 'Max speed' to numeric
df['Max speed'] = pd.to_numeric(df['Max speed'])

# Group by 'Animal' and get the first row of each group
d = df.groupby('Animal').first()

print("\nOriginal DataFrame\n", df)
print("\nGroup by Animal using first\n", d)
# Out:
# Original DataFrame
#      Animal  Max speed
# 0    Tiger        130
# 1     Lion        110
# 2  Cheetah        180
# 3     Deer        160
#
# Group by Animal using first
#           Max speed
# Animal
# Cheetah        180
# Deer           160
# Lion           110
# Tiger          130

# %%
import pandas as pd

# Original DataFrame
df = pd.DataFrame({
    'Animal': ['Tiger', 'Lion', 'Cheetah', 'Deer'],
    'Max speed': ['130', '110', '180', '160']
})

# Convert 'Max speed' to numeric
df['Max speed'] = pd.to_numeric(df['Max speed'])

# Group by 'Animal' and get the last row of each group
e = df.groupby('Animal').last()

print("\nOriginal DataFrame\n", df)
print("\nGroup by Animal using last\n", e)
# Out:
# Original DataFrame
#      Animal  Max speed
# 0    Tiger        130
# 1     Lion        110
# 2  Cheetah        180
# 3     Deer        160
#
# Group by Animal using last
#           Max speed
# Animal
# Cheetah        180
# Deer           160
# Lion           110
# Tiger          130

# %%
import pandas as pd

# Original DataFrame
df = pd.DataFrame({
    'Animal': ['Tiger', 'Lion', 'Cheetah', 'Deer'],
    'Max speed': ['130', '110', '180', '160']
})

# Convert 'Max speed' to numeric
df['Max speed'] = pd.to_numeric(df['Max speed'])

# Group by 'Animal' and get the size of each group
f = df.groupby('Animal').size()

print("\nOriginal DataFrame\n", df)
print("\nGroup by Animal using size\n", f)
# Out:
# Original DataFrame
#      Animal  Max speed
# 0    Tiger        130
# 1     Lion        110
# 2  Cheetah        180
# 3     Deer        160
#
# Group by Animal using size
#  Animal
# Cheetah    1
# Deer       1
# Lion       1
# Tiger      1
# dtype: int64
